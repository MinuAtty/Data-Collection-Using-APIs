# %%
# Install the Kaggle Python package for accessing datasets and competitions from Kaggle
! pip install kaggle

# %%
# Import the `drive` module from Google Colab to access Google Drive
from google.colab import drive

# Mount Google Drive to the Colab environment at the `/content/drive` directory
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Create a directory named `.kaggle` in the home directory
# This directory is required to store the Kaggle API key file (`kaggle.json`)
! mkdir ~/.kaggle

# %%
# Copy the `kaggle.json` file (which contains API credentials) from Google Drive
# Replace `/content/drive/MyDrive/kaggle.json` with the path where `kaggle.json` is stored in your Drive
! cp /content/drive/MyDrive/kaggle.json ~/.kaggle/

# %%
# Set file permissions for the `kaggle.json` file to ensure it's secure
# The permission `600` allows only the owner to read and write to the file
! chmod 600 ~/.kaggle/kaggle.json

# %%
# Download the dataset from Kaggle using the specified dataset ID
# The ID here is `mdfahimbinamin/fastsurfer-processed-3d-brain-mri-from-adni`
# This will download the dataset as a `.zip` file
! kaggle datasets download mdfahimbinamin/fastsurfer-processed-3d-brain-mri-from-adni
# Out:
# Dataset URL: https://www.kaggle.com/datasets/mdfahimbinamin/fastsurfer-processed-3d-brain-mri-from-adni
# License(s): apache-2.0
# ...
#  99% 2.33G/2.34G [00:23<00:00, 122MB/s]
# 100% 2.34G/2.34G [00:23<00:00, 106MB/s]

# %%
# Unzip the downloaded dataset file into the current working directory
# The `.zip` file is extracted, making the dataset ready for use
! unzip fastsurfer-processed-3d-brain-mri-from-adni.zip
# Out:
# Archive:  fastsurfer-processed-3d-brain-mri-from-adni.zip
#   inflating: FastSurfer_Processed_3D_Brain_MRI_ADNI/137_S_0443/FastSurfer LOG.txt
#   inflating: FastSurfer_Processed_3D_Brain_MRI_ADNI/137_S_0443/PreProcessed/my_fastsurfer_analysis/subjectX/label/BA_exvivo.ctab
#   inflating: FastSurfer_Processed_3D_Brain_MRI_ADNI/137_S_0443/PreProcessed/my_fastsurfer_analysis/subjectX/label/BA_exvivo.thresh.ctab
#   inflating: FastSurfer_Processed_3D_Brain_MRI_ADNI/137_S_0443/PreProcessed/my_fastsurfer_analysis/subjectX/label/aparc.annot.mapped.ctab
#   inflating: FastSurfer_Processed_3D_Brain_MRI_ADNI/137_S_0443/PreProcessed/my_fastsurfer_analysis/subjectX/label/lh.BA1_exvivo.label
#   inflating: FastSurfer_Processed_3D_Brain_MRI_ADNI/137_S_0443/PreProcessed/my_fastsurfer_analysis/subjectX/label/lh.BA1_exvivo.thresh.label
#   inflating: FastSurfer_Processed_3D_Brain_MRI_ADNI/137_S_0443/PreProcessed/my_fastsurfer_analysis/subjectX/label/lh.BA2_exvivo.label
# ...
